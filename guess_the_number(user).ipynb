# %%
import random

def guess_the_number():
    print("Welcome to the Guess the Number Game!")
    print("Please think of a number between 1 and 100.")

    low = 1
    high = 100

    while True:
        guess = random.randint(low, high)
        print(f"My guess is: {guess}")

        user_response = input("Is my guess higher (H), lower (L), or correct (C)? ")

        if user_response.upper() == "H":
            high = guess - 1
        elif user_response.upper() == "L":
            low = guess + 1
        elif user_response.upper() == "C":
            print("Yay! You guessed the number correctly!")
            break
        else:
            print("Invalid input. Please enter H, L, or C.")

if __name__ == "__main__":
    guess_the_number()
# Out:
# Welcome to the Guess the Number Game!
# Please think of a number between 1 and 100.
# My guess is: 21
# Is my guess higher (H), lower (L), or correct (C)? L
# My guess is: 91
# Is my guess higher (H), lower (L), or correct (C)? H
# My guess is: 70
# Is my guess higher (H), lower (L), or correct (C)? H
# My guess is: 50
# Is my guess higher (H), lower (L), or correct (C)? C
# Yay! You guessed the number correctly!
