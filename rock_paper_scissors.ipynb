# %%
import random
def play():
  choices = ["rock" , "paper" , "scissor"]
  for i in range(3):
      user_choice = input("What's your choice? rock, paper,scissor: ").lower()
      if user_choice not in choices:
          print("Invalid choice! Please choose rock, paper, or scissors.")
          continue

      computer_choice = random.choice(choices)
      print(f"\nYou choose: {user_choice}")
      print(f"Computer choose: {computer_choice}")

      if user_choice == computer_choice:
        print(f"{user_choice}.Game tie!")
      elif user_choice == "rock" and computer_choice == "scissor":
        print(f"{user_choice}.You won!")
      elif user_choice == "scissor" and computer_choice == "paper":
        print(f"{user_choice}.You won!")
      elif user_choice == "paper" and computer_choice == "rock":
        print(f"{user_choice}.You won!")
      else:
        print(f"{computer_choice}.Unfortunately, You lost!")

play()
# Out:
# What's your choice? rock, paper,scissor: rock
#
# You choose: rock
# Computer choose: paper
# paper.Unfortunately, You lost!
# What's your choice? rock, paper,scissor: paper
#
# You choose: paper
# Computer choose: rock
# paper.You won!
# What's your choice? rock, paper,scissor: scissor
#
# You choose: scissor
# Computer choose: scissor
# scissor.Game tie!
